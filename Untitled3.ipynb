# %%
 
#day4 
#Print the first Armstrong number in the range of 1042000 to 702648265 and exit the loop as soon you encounter the first Armstrong number. Using while loop
 
for num in range(1042000,702648265):
  temp=num
  sum=0
  while (temp>0):
      digit=temp%10
      sum=sum+digit**7
      temp=temp//10
      if sum==num:
           print (num)
# Out:
# 1741725
# 2097280
# 2097281
# 3278756
# 4210818
# 4782969
# 4861095
# 9800817
# 9926315
